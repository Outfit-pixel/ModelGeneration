# %%
# !git clone https://github.com/Outfit-pixel/ModelGeneration.git
# Out:
# Cloning into 'ModelGeneration'...
# remote: Enumerating objects: 15, done.
# remote: Counting objects: 100% (15/15), done.
# remote: Compressing objects: 100% (14/14), done.
# remote: Total 15 (delta 0), reused 15 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (15/15), 8.00 KiB | 910.00 KiB/s, done.

# %%
# !pip install torch torchvision lpips sentence-transformers transformers tqdm numpy pandas
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 70.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 54.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 37.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 10.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 88.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.8/53.8 kB 5.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
# !python /content/drive/MyDrive/Model_Generation-anurag/Complete/ModelGeneration/main.py
# Out:
# 2025-03-27 21:00:43.789037: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1743109243.811634   10225 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1743109243.818517   10225 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-03-27 21:00:43.840700: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
from config import current_dir, image_folder, device, VQVAE_CONFIG

print(f"Device: {device}")
print(f"Current dir: {current_dir}")
print(f"Image folder exists: {image_folder.exists()}")
print(f"VQVAE config: {VQVAE_CONFIG}")
# Out:
# Device: cuda
# Current dir: /content/drive/MyDrive/Model_Generation-anurag/Complete/ModelGeneration
# Image folder exists: True
# VQVAE config: {'ch': 128, 'ch_mult': (1, 2, 4, 8), 'num_res_blocks': 2, 'in_channels': 3, 'z_channels': 32, 'num_embeddings': 1024, 'embedding_dim': 32, 'beta': 0.25, 'decay': 0.99}

# %%
# %cd /content/drive/MyDrive/Model_Generation-anurag/Complete/ModelGeneration
# Out:
# /content/drive/MyDrive/Model_Generation-anurag/Complete/ModelGeneration

# %%
# !pip install lpips
